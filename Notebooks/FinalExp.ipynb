# %%
from FullyMobile import PROJECT_ROOT
import json
import seaborn as sns
import pandas as pd
import os

# %% [markdown]
# ### Budget Sensitivity

# %% [markdown]
# #### Charlottesville City:

# %%
dict_frame = {}

dict_frame["k"] = []
dict_frame["seed"] = []
dict_frame["algorithm"] = []
dict_frame["facilities"] = []
dict_frame["objective"] = []

cover_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"cover") if run.endswith('.json') and "cville" in run]
for file in cover_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"cover"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["cover" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

supplier_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"supplier") if run.endswith('.json') and "cville" in run]
for file in supplier_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"supplier"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["supplier" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]
        
baseline_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"baseline") if run.endswith('.json') and "cville" in run]
for file in baseline_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"baseline"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["baseline" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

flow_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"flow") if run.endswith('.json') and "cville" in run]
for file in flow_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"flow"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["flow" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
# Out:
#       k       seed algorithm  \
# 0     3  923650566     cover
# 1     4  923650566     cover
# 2     5  923650566     cover
# 3     6  923650566     cover
# 4     7  923650566     cover
# ..   ..        ...       ...
# 315   6  900538662      flow
# 316   7  900538662      flow
# 317   8  900538662      flow
# 318   9  900538662      flow
# 319  10  900538662      flow
#
#                                             facilities  objective
# 0    [[1466629, 77672, 2626728, 2127148, 2547806, 2...   2.883665
# 1    [[42223, 2390131, 43022, 2337775, 1809960, 228...   2.337281
# 2    [[98326, 2626728, 2390164, 2574240, 1942475, 7...   1.728476
# 3    [[1519549, 385972, 2494984, 2653281, 2311428, ...   1.483139
# 4    [[201428, 2285133, 69699, 1598501, 2600265, 27...   1.307845
# ..                                                 ...        ...
# 315  [[122888, 122888, 106561, 16445, 73758, 254783...   2.525314
# 316  [[122888, 131099, 122888, 98326, 98326, 98326,...   2.421315
# ...

# %% [markdown]
# #### Albemarle County:

# %%
dict_frame = {}

dict_frame["k"] = []
dict_frame["seed"] = []
dict_frame["algorithm"] = []
dict_frame["facilities"] = []
dict_frame["objective"] = []

cover_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"cover") if run.endswith('.json') and "albe" in run]
for file in cover_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"cover"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["cover" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

supplier_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"supplier") if run.endswith('.json') and "albe" in run]
for file in supplier_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"supplier"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["supplier" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]
        
baseline_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"baseline") if run.endswith('.json') and "albe" in run]
for file in baseline_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"baseline"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["baseline" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

flow_runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"flow") if run.endswith('.json') and "albe" in run]
for file in flow_runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"budget_sensitivity"/"flow"/file) as f:
        data = json.load(f)
        seed = data[0]
        data = data[1]
        dict_frame["facilities"] += [val["paths"] for val in data.values()]
        dict_frame["seed"] += [seed for key in data.keys()]
        dict_frame["k"] += [key for key in data.keys()]
        dict_frame["algorithm"] += ["flow" for key in data.keys()]
        dict_frame["objective"] += [val["objective"] for val in data.values()]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe
# Out:
#       k       seed algorithm  \
# 0     6  980781099     cover
# 1     7  980781099     cover
# 2     8  980781099     cover
# 3     9  980781099     cover
# 4    10  980781099     cover
# ..   ..        ...       ...
# 595  16  259019757      flow
# 596  17  259019757      flow
# 597  18  259019757      flow
# 598  19  259019757      flow
# 599  20  259019757      flow
#
#                                             facilities  objective
# 0    [[2653180, 2232212, 2363848, 2468507, 2127113,...  13.890480
# 1    [[2390040, 2653185, 2468559, 2021595, 2442377,...  10.768462
# 2    [[2258391, 2416273, 1281891, 1545836, 2153310,...  10.366539
# 3    [[2626636, 95227, 2732407, 2153310, 2442463, 2...  10.009247
# 4    [[2600184, 2732407, 33045, 2679450, 2705855, 2...   9.314950
# ..                                                 ...        ...
# 595  [[491531, 68735, 1493400, 98326, 98326, 98326,...   9.014107
# 596  [[491531, 68735, 1493400, 98326, 98326, 98345,...   8.831429
# ...

# %% [markdown]
# #### Combined Plot:

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, figsize=(6, 7))

plot = sns.lineplot(data = df_cville, x="k", y="objective", hue="algorithm", ax=axs[0])
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Number of Facilities, k")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="k", y="objective", hue="algorithm", ax=axs[1], legend=False)
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Number of Facilities, k")
plot.set_title("Albemarle County")

#plt.suptitle("Budget Sensitivity", fontsize=14)
#plt.legend(title='Algorithm', labels=['Cover', 'K-Supplier'])
plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_budget_sensitivity_robust_v.png", bbox_inches = 'tight', dpi=300)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, figsize=(7, 3))

plot = sns.lineplot(data = df_cville, x="k", y="objective", hue="algorithm", ax=axs[0], legend=False)
axs[0].set_xlim((0, 7))
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Number of Facilities, k")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="k", y="objective", hue="algorithm", ax=axs[1], legend=True)
handles, labels = axs[1].get_legend_handles_labels()
plot.legend().remove()
#sns.move_legend(plot, loc='upper left', bbox_to_anchor=(1, 1), title="Algorithm")
plot.set_ylabel("")
axs[1].set_xticks(range(0, 16, 2))
axs[1].set_xlim((0, 14))
plot.set_xlabel("Number of Facilities, k")
plot.set_title("Albemarle County")

fig.legend(handles, labels, loc='upper center', title="Algorithms", ncol = 4, bbox_to_anchor=(0.55, 0.05))

#plt.suptitle("Budget Sensitivity", fontsize=14)
#plt.legend()
plt.tight_layout()
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_budget_sensitivity_robust_h.png", bbox_inches = 'tight', dpi=300)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(15, 10))

plot = sns.lineplot(data = df_cville, x="k", y="objective", hue="algorithm", ax=axs[0][0])
plot.set_ylabel("Objective (km)")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="k", y="objective", hue="algorithm", ax=axs[0][1])
plot.set_ylabel("")
plot.set_title("Albemarle County")

df_cville_r = df_cville[df_cville['algorithm']=='cover'].copy()
df_cville_r['ratio'] = df_cville_r.apply(lambda x: df_cville[(df_cville['algorithm']=='supplier') & (df_cville['seed']==x['seed']) & (df_cville['k']==x['k'])]['objective'].iloc[0]/x['objective'], axis=1)

plot = sns.lineplot(data=df_cville_r, x='k', y='ratio', ax = axs[1][0])
plot.set_ylabel("Ratio of Objectives (supplier/cover)")
plot.set_xlabel("Number of Facilities, k")

df_albe_r = df_albe[df_albe['algorithm']=='cover'].copy()
df_albe_r['ratio'] = df_albe_r.apply(lambda x: df_albe[(df_albe['algorithm']=='supplier') & (df_albe['seed']==x['seed']) & (df_albe['k']==x['k'])]['objective'].iloc[0]/x['objective'], axis=1)

plot = sns.lineplot(data=df_albe_r, x='k', y='ratio', ax = axs[1][1])
plot.set_ylabel("")
plot.set_xlabel("Number of Facilities, k")

fig.suptitle("Budget Sensitivity: Ratio of Objectives", fontsize=14)
plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_budget_sensitivity_robust_full.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ### Percentile Coverage

# %% [markdown]
# #### Charlottesville City:

# %%
dict_frame = {}
m = 5
k = 5
with open(PROJECT_ROOT/"Experiments"/"output"/f"percentile_sensitivity_{m}_{k}_narrow_robust_baseline.json") as f:
    data = json.load(f)
    percentile = data["percentile_list"]
    dict_frame["seed"] = [seed[0] for seed in data["cover"] for _ in percentile] + [seed[0] for seed in data["supplier"] for _ in percentile] + [seed[0] for seed in data["baseline"] for _ in percentile]  + [seed[0] for seed in data["flow"] for _ in percentile]
    dict_frame["algorithm"] = ["cover" for _ in data["cover"] for _ in percentile] + ["supplier" for _ in data["supplier"] for _ in percentile] + ["baseline" for _ in data["baseline"] for _ in percentile]  + ["flow" for _ in data["flow"] for _ in percentile]
    dict_frame["fac"] = [path[1]["paths"] for path in data["cover"] for _ in percentile] + [path[1]["paths"] for path in data["supplier"] for _ in percentile] + [path[1]["paths"] for path in data["baseline"] for _ in percentile]  + [path[1]["paths"] for path in data["flow"] for _ in percentile]
    dict_frame["percentile"] = [p for _ in data["cover"] for p in percentile] + [p for _ in data["supplier"] for p in percentile] + [p for _ in data["baseline"] for p in percentile]  + [p for _ in data["flow"] for p in percentile]
    dict_frame["objective"] = [obj for obj_list in data["cover"] for obj in obj_list[1]["obj_list"]] + [obj for obj_list in data["supplier"] for obj in obj_list[1]["obj_list"]] + [obj for obj_list in data["baseline"] for obj in obj_list[1]["obj_list"]] + [obj for obj_list in data["flow"] for obj in obj_list[1]["obj_list"]]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
# Out:
#            seed algorithm                                                fac  \
# 0     923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# 1     923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# 2     923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# 3     923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# 4     923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# ...         ...       ...                                                ...
# 8035  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
# 8036  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
# 8037  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
# 8038  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
# 8039  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
#
#       percentile  objective
# ...

# %% [markdown]
# #### Albemarle County:

# %%
dict_frame = {}

m = 5
k = 10

with open(PROJECT_ROOT/"Experiments"/"output"/f"albe_percentile_sensitivity_{m}_{k}_narrow_robust.json") as f:
    data = json.load(f)
    percentile = data["percentile_list"]
    dict_frame["seed"] = [seed[0] for seed in data["cover"] for _ in percentile] + [seed[0] for seed in data["supplier"] for _ in percentile]  + [seed[0] for seed in data["baseline"] for _ in percentile] + [seed[0] for seed in data["flow"] for _ in percentile]
    dict_frame["algorithm"] = ["cover" for _ in data["cover"] for _ in percentile] + ["supplier" for _ in data["supplier"] for _ in percentile] + ["baseline" for _ in data["baseline"] for _ in percentile] + ["flow" for _ in data["flow"] for _ in percentile]
    dict_frame["fac"] = [path[1]["paths"] for path in data["cover"] for _ in percentile] + [path[1]["paths"] for path in data["supplier"] for _ in percentile] + [path[1]["paths"] for path in data["baseline"] for _ in percentile] + [path[1]["paths"] for path in data["flow"] for _ in percentile]
    dict_frame["percentile"] = [p for _ in data["cover"] for p in percentile] + [p for _ in data["supplier"] for p in percentile] + [p for _ in data["baseline"] for p in percentile] + [p for _ in data["flow"] for p in percentile]
    dict_frame["objective"] = [obj for obj_list in data["cover"] for obj in obj_list[1]["obj_list"]] + [obj for obj_list in data["supplier"] for obj in obj_list[1]["obj_list"]] + [obj for obj_list in data["baseline"] for obj in obj_list[1]["obj_list"]]+ [obj for obj_list in data["flow"] for obj in obj_list[1]["obj_list"]]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe
# Out:
#            seed algorithm                                                fac  \
# 0     980781099     cover  [[2600184, 2732407, 33045, 2679450, 2705855, 2...
# 1     980781099     cover  [[2600184, 2732407, 33045, 2679450, 2705855, 2...
# 2     980781099     cover  [[2600184, 2732407, 33045, 2679450, 2705855, 2...
# 3     980781099     cover  [[2600184, 2732407, 33045, 2679450, 2705855, 2...
# 4     980781099     cover  [[2600184, 2732407, 33045, 2679450, 2705855, 2...
# ...         ...       ...                                                ...
# 8035  262180973      flow  [[15, 134074, 2600090, 1703991, 1704093, 98326...
# 8036  262180973      flow  [[15, 134074, 2600090, 1703991, 1704093, 98326...
# 8037  262180973      flow  [[15, 134074, 2600090, 1703991, 1704093, 98326...
# 8038  262180973      flow  [[15, 134074, 2600090, 1703991, 1704093, 98326...
# 8039  262180973      flow  [[15, 134074, 2600090, 1703991, 1704093, 98326...
#
#       percentile  objective
# ...

# %% [markdown]
# #### Combined Plot:

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(6, 7))

plot = sns.lineplot(data = df_cville, x="percentile", y="objective", hue = "algorithm", ax=axs[0])
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Percentile")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="percentile", y="objective", hue = "algorithm", ax=axs[1], legend=False)
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Percentile")
plot.set_title("Albemarle County")

plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_percentile_coverage_narrow_robust_v.png", bbox_inches = 'tight', dpi=300)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, figsize=(7, 3))

plot = sns.lineplot(data = df_cville, x="percentile", y="objective", hue = "algorithm", ax=axs[0], legend=False)
axs[0].set_xlim((80, 100))
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Percentile")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="percentile", y="objective", hue = "algorithm", ax=axs[1], legend=True)
handles, labels = axs[1].get_legend_handles_labels()
axs[1].set_xlim((80, 100))
plot.legend().remove()
plot.set_ylabel("")
plot.set_xlabel("Percentile")
plot.set_title("Albemarle County")

fig.legend(handles, labels, loc='upper center', title="Algorithms", ncol = 4, bbox_to_anchor=(0.55, 0.05))

#plt.legend()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15)
#plt.show()
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_percentile_coverage_narrow_robust_h.png", bbox_inches = 'tight', dpi=300)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(15, 10))

plot = sns.lineplot(data = df_cville, x="percentile", y="objective", hue = "algorithm", ax=axs[0][0])
plot.set_ylabel("Objective (km)")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="percentile", y="objective", hue = "algorithm", ax=axs[0][1])
plot.set_ylabel("")
plot.set_title("Albemarle County")

df_cville_r = df_cville[df_cville['algorithm']=='cover'].copy()
df_cville_r['ratio'] = df_cville_r.apply(lambda x: df_cville[(df_cville['algorithm']=='supplier') & (df_cville['seed']==x['seed']) & (df_cville['percentile']==x['percentile'])]['objective'].iloc[0]/x['objective'], axis=1)

plot = sns.lineplot(data=df_cville_r, x='percentile', y='ratio', ax = axs[1][0])
plot.set_ylabel("Ratio of Objectives (supplier/cover)")
plot.set_xlabel("Percentile")

df_albe_r = df_albe[df_albe['algorithm']=='cover'].copy()
df_albe_r['ratio'] = df_albe_r.apply(lambda x: df_albe[(df_albe['algorithm']=='supplier') & (df_albe['seed']==x['seed']) & (df_albe['percentile']==x['percentile'])]['objective'].iloc[0]/x['objective'], axis=1)

plot = sns.lineplot(data=df_albe_r, x='percentile', y='ratio', ax = axs[1][1])
plot.set_ylabel("")
plot.set_xlabel("Percentile")

fig.suptitle("Percentile Coverage: Ratio of Objectives", fontsize=14)

plt.suptitle("Percentile Coverage", fontsize=14)
plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_percentile_coverage_narrow_robust_full.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ### Movement Sensitivity

# %% [markdown]
# #### Cover

# %% [markdown]
# ##### Charlottesville City:

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover") if run.endswith('.json') and "cville" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["cover_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
# Out:
#                                                     fac  objective    m   k  \
# 0     [[306969, 70635, 2521232, 1097361, 2626728, 26...   2.872070  1.0   3
# 1     [[2390169, 131949, 2337742, 77885, 2100698, 20...   2.572837  1.0   4
# 2     [[1889554, 2100792, 129739, 2258515, 1889554, ...   1.956189  1.0   5
# 3     [[1466657, 1255603, 76064, 2416397, 2416397, 2...   1.775369  1.0   6
# 4     [[1942475, 103164, 675617, 42188, 129854, 2521...   1.583322  1.0   7
# ...                                                 ...        ...  ...  ..
# 1195  [[2574240, 2311428, 544130, 96821, 2600356, 23...   1.490357  8.0   6
# 1196  [[2653281, 2653280, 2574282, 95526, 1889549, 1...   1.228726  8.0   7
# 1197  [[2653281, 1598501, 2442419, 728600, 1889549, ...   1.164956  8.0   8
# 1198  [[2494984, 1308370, 2521304, 2337742, 2390169,...   1.044025  8.0   9
# 1199  [[2574240, 2626728, 1071104, 130653, 1651480, ...   0.957802  8.0  10
#
#            seed
# 0     690104470
# 1     690104470
# ...

# %% [markdown]
# ##### Albemarle County:

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["cover_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe
# Out:
#                                                     fac  objective    m   k  \
# 0     [[2127113, 1493048, 134723, 1360892, 1308252, ...  16.938009  1.0   6
# 1     [[2705904, 2468571, 2705985, 728510, 1757197, ...  12.106198  1.0   8
# 2     [[2206176, 2468571, 2626691, 82948, 2626691, 2...  10.636744  1.0  10
# 3     [[1968801, 306861, 77671, 2153310, 2416273, 19...   9.811223  1.0  12
# 4     [[2626641, 2127041, 1863025, 2732407, 2416282,...   8.560563  1.0  14
# ...                                                 ...        ...  ...  ..
# 1195  [[134547, 1282034, 51157, 2653245, 2732437, 24...   7.136594  8.0  12
# 1196  [[134206, 135409, 2494920, 135409, 2206172, 13...   6.335865  8.0  14
# 1197  [[134948, 132635, 306907, 135791, 135001, 1357...   5.904969  8.0  16
# 1198  [[134530, 129992, 2495016, 132629, 132629, 131...   5.172432  8.0  18
# 1199  [[134530, 111251, 134340, 132629, 132629, 1093...   5.085783  8.0  20
#
#        seed
# 0     19144
# 1     19144
# 2     19144
# ...

# %% [markdown]
# ##### Combined Plots:

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(6, 8))

plot = sns.lineplot(data=df_cville, x='m', y='objective', hue='k', legend='full', ax=axs[0])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Charlottesville City")

plot = sns.lineplot(data=df_albe, x='m', y='objective', hue='k', legend='full', ax=axs[1])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Albemarle County")

plt.tight_layout()
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_movement_sensitivity_narrow_robust_v.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# #### Baseline

# %% [markdown]
# ##### Charlottesville City

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline") if run.endswith('.json') and "cville" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["baseline_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
# Out:
#                                                     fac  objective    m   k  \
# 0     [[122888, 122888, 58358, 98326, 98326, 49206, ...   3.417427  1.0   3
# 1     [[2547776, 2547776, 2547776, 98345, 98345, 327...   2.850635  1.0   4
# 2     [[2547776, 98345, 32795, 32795, 93876, 32795, ...   2.745313  1.0   5
# 3     [[2547776, 1704166, 2547857, 98345, 2547776, 2...   2.004755  1.0   6
# 4     [[2547776, 1704166, 2547857, 98345, 2547776, 2...   3.577640  1.0   7
# ...                                                 ...        ...  ...  ..
# 1195  [[2547776, 131099, 98345, 122888, 73758, 12288...   2.315618  8.0   6
# 1196  [[2547776, 131099, 98345, 122888, 1704201, 492...   2.318568  8.0   7
# 1197  [[16450, 131099, 122888, 122888, 1704201, 4920...   2.143683  8.0   8
# 1198  [[16450, 131099, 106585, 122888, 1704201, 4920...   1.965395  8.0   9
# 1199  [[16450, 131099, 2547882, 122888, 1704201, 492...   1.872284  8.0  10
#
#            seed
# 0     690104470
# 1     690104470
# ...

# %% [markdown]
# ##### Albemarle County

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["baseline_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe
# Out:
#                                                     fac  objective    m   k  \
# 0     [[98560, 333682, 2232193, 32896, 1703979, 1703...  60.062834  5.5   6
# 1     [[98560, 98560, 1704387, 98560, 333682, 170438...  67.719552  5.5   8
# 2     [[98560, 98560, 134358, 98560, 98560, 98560, 9...  64.363127  5.5  10
# 3     [[98560, 333687, 333687, 98560, 98560, 98560, ...  60.062834  5.5  12
# 4     [[98560, 333687, 333687, 1270, 98560, 98560, 9...  59.464108  5.5  14
# ...                                                 ...        ...  ...  ..
# 1123  [[1149892, 1149885, 1704433, 1704433, 1149885,...  16.963869  8.0  12
# 1124  [[1149892, 1149885, 1704433, 1704433, 1149885,...  17.930257  8.0  14
# 1125  [[2101027, 1149892, 1149885, 1149885, 1149885,...  17.930257  8.0  16
# 1126  [[1546304, 1149892, 1149885, 1149885, 1149885,...  18.657706  8.0  18
# 1127  [[2425475, 1704386, 1704007, 33038, 2494725, 1...  12.820834  8.0  20
#
#        seed
# 0     80830
# 1     80830
# 2     80830
# ...

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(6, 8))

plot = sns.lineplot(data=df_cville, x='m', y='objective', hue='k', legend='full', ax=axs[0])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Charlottesville City")

plot = sns.lineplot(data=df_albe, x='m', y='objective', hue='k', legend='full', ax=axs[1])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Albemarle County")

plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_movement_sensitivity_narrow_robust_v.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# #### Flow

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"flow") if run.endswith('.json') and "cville" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"flow"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["flow_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
# Out:
#                                                     fac  objective    m   k  \
# 0     [[122888, 386065, 122888, 122888, 122888, 5172...   3.749462  1.0   3
# 1     [[122888, 254364, 98326, 98326, 1598501, 16450...   2.522929  1.0   4
# 2     [[122888, 122888, 2547876, 16445, 2547876, 492...   2.494668  1.0   5
# 3     [[122888, 98387, 2547876, 2547879, 43232, 3279...   2.336341  1.0   6
# 4     [[122888, 98387, 2547876, 2547879, 43232, 3279...   2.012911  1.0   7
# ...                                                 ...        ...  ...  ..
# 1195  [[98326, 131099, 73758, 98326, 32795, 131099, ...   2.398548  8.0   6
# 1196  [[122888, 2547855, 106561, 2547839, 98326, 327...   2.315618  8.0   7
# 1197  [[122888, 2547820, 2547912, 2547839, 98326, 98...   2.143683  8.0   8
# 1198  [[122888, 2547820, 2547907, 73758, 122888, 122...   2.042800  8.0   9
# 1199  [[122888, 73758, 2547882, 122888, 73758, 13109...   1.872284  8.0  10
#
#            seed
# 0     690104470
# 1     690104470
# ...

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"flow") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"flow"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["flow_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe
# Out:
#                                                     fac  objective    m   k  \
# 0     [[491531, 491531, 491531, 1123848, 873, 79730,...  19.293656  5.5   6
# 1     [[15, 15, 32796, 1837096, 131161, 131161, 1312...  18.304825  5.5   8
# 2     [[15, 15, 32796, 74414, 1018423, 36259, 98326,...  14.979287  5.5  10
# 3     [[15, 15, 15, 622816, 1651279, 1018044, 201214...  13.834936  5.5  12
# 4     [[15, 15, 15, 622816, 1968702, 32804, 32804, 1...  10.991559  5.5  14
# ...                                                 ...        ...  ...  ..
# 1195  [[1703952, 32796, 15, 32796, 98326, 98326, 983...  13.023401  8.0  12
# 1196  [[98326, 32796, 15, 1703952, 88, 2100510, 6228...  11.229527  8.0  14
# 1197  [[15, 622829, 1703952, 1281877, 2495121, 13119...   9.730348  8.0  16
# 1198  [[98326, 98326, 1704082, 1704326, 1609, 65915,...   9.525744  8.0  18
# 1199  [[98323, 98323, 99072, 65652, 65652, 132820, 2...   7.385215  8.0  20
#
#        seed
# 0     80830
# 1     80830
# 2     80830
# ...

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(6, 8))

plot = sns.lineplot(data=df_cville, x='m', y='objective', hue='k', legend='full', ax=axs[0])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Charlottesville City")

plot = sns.lineplot(data=df_albe, x='m', y='objective', hue='k', legend='full', ax=axs[1])
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_title("Albemarle County")

plt.tight_layout()
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_movement_sensitivity_flow_narrow_robust_v.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# #### Baseline Comparison

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"cover"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["cover_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_cover = pd.DataFrame(dict_frame)

# %%
dict_frame = {}

dict_frame["fac"] = []
dict_frame["objective"] = []
dict_frame["m"] = []
dict_frame["k"] = []
dict_frame["seed"] = []

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"movement_sensitivity"/"baseline"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        
        data = data["baseline_runs"]
        m_values = data.keys()
        k_values = data[list(data.keys())[0]].keys()
        dict_frame["fac"] += [data[m][k]["paths"] for m in m_values for k in k_values]
        dict_frame["objective"] += [data[m][k]["objective"] for m in m_values for k in k_values]
        dict_frame["m"] += [float(m) for m in m_values for k in k_values]
        dict_frame["k"] += [int(k) for m in m_values for k in k_values]
        dict_frame["seed"] += [seed for m in m_values for k in k_values]

# %%
df_baseline = pd.DataFrame(dict_frame)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, figsize=(7, 3))

plot = sns.lineplot(data=df_cover, x='m', y='objective', hue='k', ax=axs[0], legend=False)
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("Objective (km)")
axs[0].set_xlim((1, 8))
#sns.move_legend(plot, "upper center", bbox_to_anchor=(0.5, 0.1), ncol=8)
plot.set_title("Cover")

plot = sns.lineplot(data=df_baseline, x='m', y='objective', hue='k', legend='full', ax=axs[1])
handles, labels = axs[1].get_legend_handles_labels()
plot.legend().remove()
axs[1].set_xlim((1, 8))
plot.set_xlabel("Movement Budget, m (km)")
plot.set_ylabel("")
plot.set_title("Baseline")

fig.legend(handles, labels, loc='upper center', title="Number of Facilities, k", ncol = 8, bbox_to_anchor=(0.5, 0.05))

plt.tight_layout()
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_movement_sensitivity_h.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ### Capacity

# %%
dict_frame = {"seed": [], "algorithm": [], "fac": [], "obj": [], "capacity_obj": [], "constraint": []}
m = 5
k = 5
with open(PROJECT_ROOT/"Experiments"/"output"/f"cville_capacity_{m}_{k}_constraint.json") as f:
    results = json.load(f)
    for flex in results.keys():
        data = results[flex]
        dict_frame["seed"] += [seed[0] for seed in data["cover"]] + [seed[0] for seed in data["supplier"]] + [seed[0] for seed in data["baseline"]]  + [seed[0] for seed in data["flow"]]
        dict_frame["algorithm"] += ["cover" for _ in data["cover"]] + ["supplier" for _ in data["supplier"]] + ["baseline" for _ in data["baseline"]]  + ["flow" for _ in data["flow"]]
        dict_frame["fac"] += [path[1]["paths"] for path in data["cover"]] + [path[1]["paths"] for path in data["supplier"]] + [path[1]["paths"] for path in data["baseline"]]  + [path[1]["paths"] for path in data["flow"]]
        dict_frame["obj"] += [path[1]["objective"] for path in data["cover"]] + [path[1]["objective"] for path in data["supplier"]] + [path[1]["objective"] for path in data["baseline"]]  + [path[1]["objective"] for path in data["flow"]]
        dict_frame["capacity_obj"] += [path[1]["capacity_cost"] for path in data["cover"]] + [path[1]["capacity_cost"] for path in data["supplier"]] + [path[1]["capacity_cost"] for path in data["baseline"]]  + [path[1]["capacity_cost"] for path in data["flow"]]
        dict_frame["constraint"] += [flex for _ in data["cover"]] + [flex for _ in data["supplier"]] + [flex for _ in data["baseline"]] + [flex for _ in data["flow"]]

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville
#df_cville["diff"] = df_cville[["capacity_obj", "obj"]].apply(lambda x: x["capacity_obj"]-x["obj"], axis=1)
# Out:
#           seed algorithm                                                fac  \
# 0    923650566     cover  [[98326, 2626728, 2390164, 2574240, 1942475, 7...
# 1     90815805     cover  [[227937, 33913, 2416397, 2390135, 2626728, 72...
# 2    511415311     cover  [[97015, 135737, 517247, 122966, 675555, 88051...
# 3     26754324     cover  [[1809960, 2468669, 675555, 106800, 1281940, 7...
# 4    815883135     cover  [[2574282, 1968881, 135737, 132685, 96821, 231...
# ..         ...       ...                                                ...
# 275  349018100      flow  [[122888, 16444, 98326, 122888, 32795, 8233, 1...
# 276  900538662      flow  [[122888, 98326, 122888, 98326, 98326, 98326, ...
# 277  213847459      flow  [[122888, 16450, 2547820, 89, 98326, 122888, 3...
# 278  897787033      flow  [[98326, 2547776, 122888, 16450, 32795, 32795,...
# 279  313608645      flow  [[122888, 16445, 131152, 16450, 16444, 16445, ...
#
#           obj  capacity_obj constraint
# ...

# %%
dict_frame = {"seed": [], "algorithm": [], "fac": [], "obj": [], "capacity_obj": [], "constraint": []}

m = 5
k = 10

with open(PROJECT_ROOT/"Experiments"/"output"/f"albe_capacity_{m}_{k}_constraint.json") as f:
    results = json.load(f)
    for flex in results.keys():
        data = results[flex]
        
        flex = int(flex)
        dict_frame["seed"] += [seed[0] for seed in data["cover"]] + [seed[0] for seed in data["supplier"]] + [seed[0] for seed in data["baseline"]]  + [seed[0] for seed in data["flow"]]
        dict_frame["algorithm"] += ["cover" for _ in data["cover"]] + ["supplier" for _ in data["supplier"]] + ["baseline" for _ in data["baseline"]]  + ["flow" for _ in data["flow"]]
        dict_frame["fac"] += [path[1]["paths"] for path in data["cover"]] + [path[1]["paths"] for path in data["supplier"]] + [path[1]["paths"] for path in data["baseline"]]  + [path[1]["paths"] for path in data["flow"]]
        dict_frame["obj"] += [path[1]["objective"] for path in data["cover"]] + [path[1]["objective"] for path in data["supplier"]] + [path[1]["objective"] for path in data["baseline"]]  + [path[1]["objective"] for path in data["flow"]]
        dict_frame["capacity_obj"] += [path[1]["capacity_cost"] for path in data["cover"]] + [path[1]["capacity_cost"] for path in data["supplier"]] + [path[1]["capacity_cost"] for path in data["baseline"]]  + [path[1]["capacity_cost"] for path in data["flow"]]
        dict_frame["constraint"] += [flex for _ in data["cover"]] + [flex for _ in data["supplier"]] + [flex for _ in data["baseline"]] + [flex for _ in data["flow"]]

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe = df_albe[df_albe['constraint']<=25]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(6, 7))

plot = sns.lineplot(data = df_cville, x="constraint", y="capacity_obj", hue = "algorithm", ax=axs[0])
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Capacity")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="constraint", y="capacity_obj", hue = "algorithm", ax=axs[1], legend=False)
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Capacity")
plot.set_title("Albemarle County")

plt.tight_layout()
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_capacity_robust_v.png", bbox_inches = 'tight', dpi=300)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, figsize=(6, 3))

plot = sns.lineplot(data = df_cville, x="constraint", y="capacity_obj", hue = "algorithm", ax=axs[0], legend=False)
#sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))
axs[0].set_xlim((0, 6))
plot.set_ylabel("Objective (km)")
plot.set_xlabel("Capacity")
plot.set_title("Charlottesville City")

plot = sns.lineplot(data = df_albe, x="constraint", y="capacity_obj", hue = "algorithm", ax=axs[1], legend=True)
#plot.set_ylabel("Objective (km)")
handles, labels = axs[1].get_legend_handles_labels()
axs[1].set_xlim((14, 25))
axs[1].set_xticks(range(14, 25, 2))
plot.set_ylabel("")
plot.legend().remove()
plot.set_xlabel("Capacity")
plot.set_title("Albemarle County")

fig.legend(handles, labels, loc='upper center', title="Algorithms", ncol = 4, bbox_to_anchor=(0.55, 0.05))

plt.tight_layout()
plt.subplots_adjust(wspace=0.15)
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_capacity_robust_h.png", bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ### Priority Weighted Inequality

# %%
dict_frame = {"class": [], "obj": [], "weighted": [], "seed": [], "pid": [], "weight": [], "weighted_obj":[]}

"""TODO: take average over all population instances before plotting boxplot? (pid and weighted)"""

class_dict = {1: "Low", 2:"Middle", 3: "High"}

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"weighted_inequality") if run.endswith('.json') and "cville" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"weighted_inequality"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        weighted_group = data["weighted"]
        unweighted_group = data["unweighted"]

        for g in weighted_group.keys():
            for pid, pid_obj in weighted_group[g].items():
                dict_frame["weight"].append(g)
                dict_frame["class"].append(class_dict[int(float(g))])
                dict_frame["obj"].append(pid_obj)
                dict_frame["weighted_obj"].append(1/float(g)*pid_obj)
                dict_frame["weighted"].append("Weighted")
                dict_frame["seed"].append(seed)
                dict_frame["pid"].append(pid)

        for g in unweighted_group.keys():
            for pid, pid_obj in unweighted_group[g].items():
                dict_frame["weight"].append(g)
                dict_frame["class"].append(class_dict[int(float(g))])
                dict_frame["obj"].append(pid_obj)
                dict_frame["weighted_obj"].append(1/float(g)*pid_obj)
                dict_frame["weighted"].append("Unweighted")
                dict_frame["seed"].append(seed)
                dict_frame["pid"].append(pid)

# %%
from pandas.api.types import CategoricalDtype
cat_group_order = CategoricalDtype(
    ['Low', 'Middle', 'High'], 
    ordered=True
)

# %%
df_cville = pd.DataFrame(dict_frame)
df_cville = df_cville.groupby(['weighted', 'pid', 'class']).mean()
df_cville.reset_index(inplace=True)
df_cville['class']=df_cville['class'].astype(cat_group_order)
df_cville = df_cville.sort_values(by=['class'])
df_cville
# Out:
#         weighted      pid class       obj         seed  weighted_obj
# 0     Unweighted  5586585   Low  0.572040  349018100.0      0.572040
# 6684    Weighted  5602190   Low  0.980155   26754324.0      0.980155
# 2706  Unweighted  5609386   Low  0.250304  213847459.0      0.250304
# 6681    Weighted  5602153   Low  0.581334  511415311.0      0.581334
# 2714  Unweighted  5609480   Low  1.780449  213847459.0      1.780449
# ...          ...      ...   ...       ...          ...           ...
# 3790  Unweighted  5618887  High  1.175322  856835084.0      0.391774
# 3791  Unweighted  5618891  High  1.663400  923650566.0      0.554467
# 2046  Unweighted  5603591  High  0.479824  897787033.0      0.159941
# 3779  Unweighted  5618738  High  1.689170  815883135.0      0.563057
# 4642  Unweighted  5625981  High  1.008371  349018100.0      0.336124
#
# [9642 rows x 6 columns]

# %%
dict_frame = {"class": [], "obj": [], "weighted": [], "seed": [], "pid": [], "weight":[], "weighted_obj":[]}

runs = [run for run in os.listdir(PROJECT_ROOT/"Experiments"/"output"/"weighted_inequality") if run.endswith('.json') and "albe" in run]
for file in runs:
    with open(PROJECT_ROOT/"Experiments"/"output"/"weighted_inequality"/file) as f:
        data = json.load(f)
        seed = int(data["seed"])
        weighted_group = data["weighted"]
        unweighted_group = data["unweighted"]

        for g in weighted_group.keys():
            for pid, pid_obj in weighted_group[g].items():
                dict_frame["weight"].append(g)
                dict_frame["class"].append(class_dict[int(float(g))])
                dict_frame["obj"].append(pid_obj)
                dict_frame["weighted_obj"].append(1/float(g)*pid_obj)
                dict_frame["weighted"].append("Weighted")
                dict_frame["seed"].append(seed)
                dict_frame["pid"].append(pid)

        for g in unweighted_group.keys():
            for pid, pid_obj in unweighted_group[g].items():
                dict_frame["weight"].append(g)
                dict_frame["class"].append(class_dict[int(float(g))])
                dict_frame["obj"].append(pid_obj)
                dict_frame["weighted_obj"].append(1/float(g)*pid_obj)
                dict_frame["weighted"].append("Unweighted")
                dict_frame["seed"].append(seed)
                dict_frame["pid"].append(pid)

# %%
df_albe = pd.DataFrame(dict_frame)
df_albe = df_albe.groupby(['weighted', 'pid', 'class']).mean()
df_albe.reset_index(inplace=True)
df_albe['class']=df_albe['class'].astype(cat_group_order)
df_albe = df_albe.sort_values(by=['class'])
df_albe
# Out:
#          weighted     pid class       obj         seed  weighted_obj
# 6105   Unweighted   58855   Low  6.734263  780346844.0      6.734263
# 20425    Weighted   93365   Low  0.609165  980781099.0      0.609165
# 2004   Unweighted  116813   Low  8.444726  780346844.0      8.444726
# 6323   Unweighted   61164   Low  6.605221  980781099.0      6.605221
# 11830    Weighted  110085   Low  1.636858  437012400.0      1.636858
# ...           ...     ...   ...       ...          ...           ...
# 10421  Unweighted   98507  High  4.227690  262180973.0      1.409230
# 10425  Unweighted   98541  High  1.634497  780346844.0      0.544832
# 10428  Unweighted   98571  High  3.749098  720331307.0      1.249699
# 10410  Unweighted   98417  High  5.003538  837663801.0      1.667846
# 21223    Weighted   99998  High  3.080560  780346844.0      1.026853
#
# [21224 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=2, figsize=(6, 3))

plot = sns.boxplot(data=df_cville, x="obj", y="class", hue="weighted", ax=axs[0])
plot.legend().remove()
plot.set_ylabel("Income Group")
plot.set_xlabel("Objective")
plot.set_title("Charlottesville City")

plot = sns.boxplot(data=df_albe, x="obj", y="class", hue="weighted", ax=axs[1])
handles, labels = axs[1].get_legend_handles_labels()
plot.set_ylabel("")
plot.legend().remove()
plot.set(yticklabels=[])
plot.set_xlabel("Objective")
plot.set_title("Albemarle County")

fig.legend(handles, labels, loc='upper center', ncol = 2, bbox_to_anchor=(0.55, 0.05))

plt.tight_layout()
plt.subplots_adjust(wspace=0.1)
plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_priority_h.png", bbox_inches = 'tight', dpi=300)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(6, 3))

plot = sns.boxplot(data=df_cville, x="weighted_obj", y="class", hue="weighted", ax=axs[0])
plot.legend().remove()
plot.set_ylabel("Income Group")
plot.set_xlabel("Weighted Objective")
plot.set_title("Charlottesville City")

plot = sns.boxplot(data=df_albe, x="weighted_obj", y="class", hue="weighted", ax=axs[1])
handles, labels = axs[1].get_legend_handles_labels()
plot.set_ylabel("")
plot.set(yticklabels=[])
plot.legend().remove()
plot.set_xlabel("Weighted Objective")
plot.set_title("Albemarle County")

fig.legend(handles, labels, loc='upper center', ncol=2, bbox_to_anchor=(0.55, 0.05))

plt.tight_layout()
plt.subplots_adjust(wspace=0.1)
#plt.savefig(PROJECT_ROOT/"Experiments"/"output"/"plots"/"combined_capacity_robust_h.png", bbox_inches = 'tight', dpi=300)

# %%
for info in [("Cville", df_cville), ("Albe", df_albe)]:
    
    name = info[0]
    df = info[1]
    
    for income_class in ['Low', 'Middle', 'High']:
        
        weighted_df = df[(df['class']==income_class) & (df['weighted']=='Weighted')]
        unweighted_df = df[(df['class']==income_class) & (df['weighted']=='Unweighted')]
        
        df_pop = weighted_df.set_index('pid')
        df_pop = df_pop.rename(columns={'obj': 'obj_w'})

        df_pop = unweighted_df[['pid', 'obj']].join(df_pop, on='pid')
        df_pop['obj_change'] = df_pop['obj']-df_pop['obj_w']
        
        print(f"---------{name} {income_class}---------")
        
        print("Prop Decrease: ", "%.2f" % (len(df_pop[df_pop['obj_change']>=0])/len(df_pop)))
        print("Change in Avg: ", "%.2f" % ((weighted_df['obj'].mean()-unweighted_df['obj'].mean())/unweighted_df['obj'].mean()))
        print("Change in Med: ", "%.2f" % ((weighted_df['obj'].median()-unweighted_df['obj'].median())/unweighted_df['obj'].median()))
        print("Change in Max: ", "%.2f" % ((weighted_df['obj'].max()-unweighted_df['obj'].max())/unweighted_df['obj'].max()))
# Out:
# ---------Cville Low---------
# Prop Decrease:  0.71
# Change in Avg:  -0.21
# Change in Med:  -0.17
# Change in Max:  -0.34
# ---------Cville Middle---------
# Prop Decrease:  0.53
# Change in Avg:  0.05
# Change in Med:  -0.03
# Change in Max:  0.30
# ---------Cville High---------
# Prop Decrease:  0.51
# Change in Avg:  0.11
# Change in Med:  0.03
# Change in Max:  0.71
# ---------Albe Low---------
# Prop Decrease:  0.67
# Change in Avg:  -0.23
# Change in Med:  -0.18
# Change in Max:  -0.38
# ---------Albe Middle---------
# Prop Decrease:  0.54
# Change in Avg:  -0.04
# Change in Med:  -0.09
# Change in Max:  0.23
# ---------Albe High---------
# Prop Decrease:  0.54
# Change in Avg:  -0.03
# Change in Med:  -0.10
# Change in Max:  0.74
